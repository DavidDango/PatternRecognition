# %%
# %matplotlib inline

from matplotlib import pyplot as plt
from skimage import io
import numpy as np

# %%
FILENAME = 'I00022.jpg'

# %%
sample = io.imread(FILENAME, as_gray=True)

# %%
plt.imshow(sample, cmap='gray')
plt.show()

# %%
file_object  = open('V004.txt', 'r').readlines()

# %%
data, header = list(), list()

for i, line in enumerate(file_object):
    if line[:3] == 'lbl':
        header.append(line)
        tmp = file_object[i + 1].replace('pos =[', '')
        tmp = tmp.replace(']', '').replace(';', '')
        data.append(list(tmp.split()))

# %%
point = list(map(float, data[0][84:88]))
# Out:
# [361.965976, 162.754736, 66.825896, 150.154971]

# %%
import matplotlib.patches as patches

# %%
fig,ax = plt.subplots(1)
ax.imshow(sample, cmap='gray')

rect = patches.Rectangle((361, 162), 66, 150, linewidth=1, 
                         edgecolor='r', facecolor='none')
ax.add_patch(rect)

# %%
(x1, y1), x2, y2

# %%
import string
file_object  = open('V000.txt', 'r')

# %%
flag = False
start = 0
end = 0
for line in file_object:
    if 'lbl=\'person\'' in line:
        flag = True
        line_t = string.replace(line, '=', ' ')
        line_t = string.split()
        start = line_t

# %%
if True:
    print('Hello!')

# %%
a = ['hello', 'wolrd', 'hate', 'somuch']

# %%
a.index('wolrd')
